# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('calib.csv')
data = data[['pi', 'q']]
data
# Out:
#            pi         q
# 0    0.000011  0.497076
# 1    0.000011  0.497076
# 2    0.000011  0.497076
# 3    0.000011  0.497032
# 4    0.008907  0.494339
# ..        ...       ...
# 155  0.001623  0.457893
# 156  0.000524  0.466367
# 157  0.000509  0.422719
# 158  0.000647  0.496708
# 159  0.001710  0.386167
#
# [160 rows x 2 columns]

# %%
def smooth(y, box_pts):
    box = np.ones(box_pts)/box_pts
    y_smooth = np.convolve(y, box, mode='same')
    return y_smooth

# %%
sort_index = np.argsort(data['pi']).values
plt.scatter(np.arange(160), (smooth(data['pi'][sort_index],4)))
plt.scatter(np.arange(160), (smooth(((data['q'][sort_index]-0.38)*0.3), 2)))
plt.show()

# %%
sort_index = np.argsort(data['pi']).values
plt.scatter(np.arange(160), (smooth(data['pi'],5)))
plt.scatter(np.arange(160), (smooth(((data['q']-0.38)*0.3), 3)))
plt.show()

# %%
sort_index = np.argsort(data['pi']).values
sort_index[:10]
# Out:
# array([  0,   1,   2,   3, 157, 156, 103, 104, 149, 158])

# %%
sort_index[-10:]
# Out:
# array([ 29, 116,  35,  16,  44,  57,   5,  24,  41,  40])

# %%
ab = np.concatenate((data['pi'][sort_index[:20]], data['pi'][sort_index[-20:]]))
cd = np.concatenate((data['q'][sort_index[:20]], data['q'][sort_index[-20:]]))

plt.scatter(np.arange(40), smooth(ab, 4))
plt.scatter(np.arange(40), smooth((cd-0.38)*0.3, 4))
plt.show()

# %%
sort_index[-10:]
# Out:
# array([ 29, 116,  35,  16,  44,  57,   5,  24,  41,  40])
